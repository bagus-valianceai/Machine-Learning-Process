# %% [markdown]
# # 4. Data Pipeline

# %% [markdown]
# ## 4.1. Import needed libraries

# %%
import os
import joblib
import sqlite3
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 4.2. Loading dataset from files

# %% [markdown]
# ### 4.2.1. Load single file dataset

# %%
def load_single_file_dataset(path: str) -> pd.DataFrame:
    '''
    Brief:
    This function intended to load a single comma separated value (CSV) file to program.

    Params:
    1.  path
        String, defining the location of target CSV file.
    
    Return:
    1.  dataset
        Pandas DataFrame that contains data from target CSV file.
    '''
    dataset = pd.read_csv(path)
    
    return dataset

# %%
dataset = load_single_file_dataset("../data/raw/files/indeks-standar-pencemar-udara-di-spku-bulan-agustus-tahun-2021.csv")

# %%
dataset
# Out:
#         tanggal                           stasiun  pm10  pm25  so2  co  o3  \
# 0    2021-08-01                DKI1 (Bunderan HI)    51    68   25   8  29
# 1    2021-08-02                DKI1 (Bunderan HI)    47    63   24  10  25
# 2    2021-08-03                DKI1 (Bunderan HI)    50    68   26  11  19
# 3    2021-08-04                DKI1 (Bunderan HI)    52    70   29   8  24
# 4    2021-08-05                DKI1 (Bunderan HI)    52    66   29   9  21
# ..          ...                               ...   ...   ...  ...  ..  ..
# 150  2021-08-27  DKI5 (Kebon Jeruk) Jakarta Barat    61    96   34   8  29
# 151  2021-08-28  DKI5 (Kebon Jeruk) Jakarta Barat    63   100   31   8  44
# 152  2021-08-29  DKI5 (Kebon Jeruk) Jakarta Barat    67   111   32  10  36
# 153  2021-08-30  DKI5 (Kebon Jeruk) Jakarta Barat    83   126   35  16  32
# 154  2021-08-31  DKI5 (Kebon Jeruk) Jakarta Barat    60    92   30   7  32
#
#      no2  max critical     categori
# 0     22   68     PM25       SEDANG
# 1     28   63     PM25       SEDANG
# 2     35   68     PM25       SEDANG
# 3     26   70     PM25       SEDANG
# 4     27   66     PM25       SEDANG
# ..   ...  ...      ...          ...
# 150   15   96     PM25       SEDANG
# 151   12  100     PM25       SEDANG
# 152   13  111     PM25  TIDAK SEHAT
# 153   29  126     PM25  TIDAK SEHAT
# 154   14   92     PM25       SEDANG
#
# [155 rows x 11 columns]

# %% [markdown]
# ### 4.2.2. Load multiple files dataset

# %%
def load_multiple_files_dataset(root_path: str) -> pd.DataFrame:
    '''
    Brief:
    This function intended to load multiple comma separated value (CSV) files to program.

    Params:
    1.  root_path
        String, defining the folder of all target CSV files located.
    
    Return:
    1.  dataset
        Pandas DataFrame that contains combined data from all target CSV files.
    '''
    list_files = os.listdir(root_path)

    list_dataset_path = [root_path + file_name for file_name in list_files]
    
    dataset = pd.DataFrame()

    for dataset_path in list_dataset_path:
        temp = pd.read_csv(dataset_path)
        dataset = pd.concat([dataset, temp])

    return dataset

# %%
dataset = load_multiple_files_dataset("../data/raw/files/")

# %%
dataset
# Out:
#         tanggal                           stasiun pm10 pm25  so2  co  o3 no2  \
# 0    2021-08-01                DKI1 (Bunderan HI)   51   68   25   8  29  22
# 1    2021-08-02                DKI1 (Bunderan HI)   47   63   24  10  25  28
# 2    2021-08-03                DKI1 (Bunderan HI)   50   68   26  11  19  35
# 3    2021-08-04                DKI1 (Bunderan HI)   52   70   29   8  24  26
# 4    2021-08-05                DKI1 (Bunderan HI)   52   66   29   9  21  27
# ..          ...                               ...  ...  ...  ...  ..  ..  ..
# 145  2021-09-26  DKI5 (Kebon Jeruk) Jakarta Barat   48   67  ---   4  30   9
# 146  2021-09-27  DKI5 (Kebon Jeruk) Jakarta Barat   51   78  ---   9  22  18
# 147  2021-09-28  DKI5 (Kebon Jeruk) Jakarta Barat   42   64  ---   5  26  14
# 148  2021-09-29  DKI5 (Kebon Jeruk) Jakarta Barat   56   87  ---  11  34  19
# 149  2021-09-30  DKI5 (Kebon Jeruk) Jakarta Barat   68  108  ---  10  46  13
#
#      max critical     categori
# 0     68     PM25       SEDANG
# 1     63     PM25       SEDANG
# 2     68     PM25       SEDANG
# 3     70     PM25       SEDANG
# 4     66     PM25       SEDANG
# ..   ...      ...          ...
# 145   67     PM25       SEDANG
# 146   78     PM25       SEDANG
# 147   64     PM25       SEDANG
# 148   87     PM25       SEDANG
# 149  108     PM25  TIDAK SEHAT
#
# [1830 rows x 11 columns]

# %% [markdown]
# ## 4.3. Loading dataset from database

# %% [markdown]
# #### 4.3.1. Connect to database

# %%
def create_connection_to_db(url_to_db: str) -> sqlite3.Connection:
    '''
    Brief:
    This function intended to create connection to specified sqlite3 database.

    Params:
    1.  url_to_db
        String, defining the sqlite3 database file located.
    
    Return:
    1.  connection
        Sqlite3 connection object.
    '''
    connection = sqlite3.connect(url_to_db)

    return connection

# %%
connection = create_connection_to_db("../data/raw/database/dataset.db")

# %%
def create_cursor_to_db(current_connection: sqlite3.Connection) -> sqlite3.Cursor:
    '''
    Brief:
    This function intended to create cursor based on established connection object. Cursor is a mechanism that enables user to traversal over the records in database.

    Params:
    1.  current_connection
        Sqlite3 connection object, defining the connection between object and database.
    
    Return:
    1.  cursor
        Sqlite3 cursor object.
    '''
    cursor = current_connection.cursor()

    return cursor

# %%
cursor = create_cursor_to_db(connection)

# %% [markdown]
# #### 4.3.2. Select data from database

# %%
def execute_query(cursor: sqlite3.Cursor, query: str) -> list:
    '''
    Brief:
    This function intended to execute any query that supported by sqlite3.

    Params:
    1.  cursor
        Sqlite3 cursor object, object that has capability to access and do traversal in target database.
    
    2.  query
        String, the query that used want to execute.
    
    Return:
    1.  result
        List, result of executed query.
    '''
    result = cursor.execute(query)
    result = result.fetchall()

    return result

# %%
result = execute_query(cursor, "SELECT * FROM ispu")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 result = execute_query(cursor, "SELECT * FROM ispu")
#
# Cell In[12], line 17, in execute_query(cursor, query)
#       1 def execute_query(cursor: sqlite3.Cursor, query: str) -> list:
#       2     '''
#       3     Brief:
#       4     This function intended to execute any query that supported by sqlite3.
#    (...)
#      15         List, result of executed query.
#      16     '''
# ---> 17     result = cursor.execute(query)
#      18     result = result.fetchall()
#      20     return result
#
# OperationalError: no such table: ispu

# %%
result
# Out:
# [('2021-08-01',
#   'DKI1 (Bunderan HI)',
#   51,
#   68,
#   25,
#   8,
#   29,
#   22,
#   68,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-02',
#   'DKI1 (Bunderan HI)',
#   47,
#   63,
#   24,
#   10,
#   25,
#   28,
#   63,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-03',
#   'DKI1 (Bunderan HI)',
#   50,
#   68,
#   26,
#   11,
#   19,
#   35,
#   68,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-04',
#   'DKI1 (Bunderan HI)',
#   52,
#   70,
#   29,
#   8,
#   24,
#   26,
#   70,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-05',
#   'DKI1 (Bunderan HI)',
#   52,
#   66,
#   29,
#   9,
#   21,
#   27,
#   66,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-06',
#   'DKI1 (Bunderan HI)',
#   56,
#   73,
#   28,
#   15,
#   11,
#   28,
#   73,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-07',
#   'DKI1 (Bunderan HI)',
#   55,
#   71,
#   31,
#   7,
#   18,
#   18,
#   71,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-08',
#   'DKI1 (Bunderan HI)',
#   53,
#   69,
#   33,
#   6,
#   23,
#   16,
#   69,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-09',
#   'DKI1 (Bunderan HI)',
#   52,
#   60,
#   30,
#   6,
#   25,
#   15,
#   60,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-10',
#   'DKI1 (Bunderan HI)',
#   32,
#   50,
#   25,
#   7,
#   29,
#   16,
#   50,
#   'PM25',
#   'BAIK',
#   None),
#  ('2021-08-11',
#   'DKI1 (Bunderan HI)',
#   55,
#   73,
#   25,
#   10,
#   24,
#   25,
#   73,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-12',
#   'DKI1 (Bunderan HI)',
#   55,
#   70,
#   28,
#   8,
#   20,
#   19,
#   70,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-13',
#   'DKI1 (Bunderan HI)',
#   56,
#   75,
#   28,
#   10,
#   17,
#   28,
#   75,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-14',
#   'DKI1 (Bunderan HI)',
#   65,
#   92,
#   30,
#   15,
#   24,
#   36,
#   92,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-15',
#   'DKI1 (Bunderan HI)',
#   56,
#   72,
#   31,
#   8,
#   17,
#   20,
#   72,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-16',
#   'DKI1 (Bunderan HI)',
#   53,
#   70,
#   30,
#   8,
#   17,
#   19,
#   70,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-17',
#   'DKI1 (Bunderan HI)',
#   56,
#   77,
#   28,
#   13,
#   26,
#   22,
#   77,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-18',
#   'DKI1 (Bunderan HI)',
#   59,
#   78,
#   25,
#   11,
#   27,
#   26,
#   78,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-19',
#   'DKI1 (Bunderan HI)',
#   60,
#   89,
#   31,
#   15,
#   24,
#   35,
#   89,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-20',
#   'DKI1 (Bunderan HI)',
#   58,
#   84,
#   29,
#   11,
#   32,
#   34,
#   84,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-21',
#   'DKI1 (Bunderan HI)',
#   59,
#   80,
#   25,
#   13,
#   26,
#   35,
#   80,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-22',
#   'DKI1 (Bunderan HI)',
#   59,
#   81,
#   28,
#   14,
#   25,
#   28,
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-23',
#   'DKI1 (Bunderan HI)',
#   56,
#   77,
#   28,
#   10,
#   25,
#   27,
#   77,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-24',
#   'DKI1 (Bunderan HI)',
#   59,
#   87,
#   27,
#   12,
#   32,
#   30,
#   87,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-25',
#   'DKI1 (Bunderan HI)',
#   62,
#   89,
#   26,
#   12,
#   34,
#   34,
#   89,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-26',
#   'DKI1 (Bunderan HI)',
#   56,
#   77,
#   27,
#   10,
#   22,
#   33,
#   77,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-27',
#   'DKI1 (Bunderan HI)',
#   62,
#   89,
#   30,
#   11,
#   25,
#   31,
#   89,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-28',
#   'DKI1 (Bunderan HI)',
#   65,
#   93,
#   26,
#   11,
#   40,
#   27,
#   93,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-29',
#   'DKI1 (Bunderan HI)',
#   65,
#   96,
#   28,
#   12,
#   30,
#   29,
#   96,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-30',
#   'DKI1 (Bunderan HI)',
#   79,
#   112,
#   27,
#   17,
#   39,
#   41,
#   112,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-31',
#   'DKI1 (Bunderan HI)',
#   64,
#   86,
#   27,
#   12,
#   35,
#   33,
#   86,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-01',
#   'DKI2 (Kelapa Gading)',
#   55,
#   75,
#   50,
#   9,
#   67,
#   13,
#   75,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-02',
#   'DKI2 (Kelapa Gading)',
#   52,
#   69,
#   50,
#   10,
#   59,
#   16,
#   69,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-03',
#   'DKI2 (Kelapa Gading)',
#   61,
#   85,
#   53,
#   12,
#   47,
#   25,
#   85,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-04',
#   'DKI2 (Kelapa Gading)',
#   64,
#   89,
#   53,
#   9,
#   50,
#   14,
#   89,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-05',
#   'DKI2 (Kelapa Gading)',
#   61,
#   79,
#   55,
#   9,
#   58,
#   18,
#   79,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-06',
#   'DKI2 (Kelapa Gading)',
#   76,
#   100,
#   58,
#   17,
#   38,
#   31,
#   100,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-07',
#   'DKI2 (Kelapa Gading)',
#   63,
#   79,
#   53,
#   8,
#   48,
#   16,
#   79,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-08',
#   'DKI2 (Kelapa Gading)',
#   60,
#   78,
#   53,
#   9,
#   57,
#   12,
#   78,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-09',
#   'DKI2 (Kelapa Gading)',
#   56,
#   67,
#   52,
#   8,
#   57,
#   10,
#   67,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-10',
#   'DKI2 (Kelapa Gading)',
#   36,
#   53,
#   48,
#   8,
#   55,
#   9,
#   55,
#   'O3',
#   'SEDANG',
#   None),
#  ('2021-08-11',
#   'DKI2 (Kelapa Gading)',
#   58,
#   83,
#   50,
#   10,
#   59,
#   17,
#   83,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-12',
#   'DKI2 (Kelapa Gading)',
#   65,
#   88,
#   52,
#   10,
#   47,
#   18,
#   88,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-13',
#   'DKI2 (Kelapa Gading)',
#   58,
#   79,
#   51,
#   10,
#   49,
#   19,
#   79,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-14',
#   'DKI2 (Kelapa Gading)',
#   69,
#   94,
#   53,
#   11,
#   53,
#   21,
#   94,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-15',
#   'DKI2 (Kelapa Gading)',
#   63,
#   84,
#   53,
#   9,
#   46,
#   16,
#   84,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-16',
#   'DKI2 (Kelapa Gading)',
#   60,
#   80,
#   54,
#   9,
#   42,
#   17,
#   80,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-17',
#   'DKI2 (Kelapa Gading)',
#   62,
#   84,
#   51,
#   9,
#   40,
#   14,
#   84,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-18',
#   'DKI2 (Kelapa Gading)',
#   59,
#   83,
#   51,
#   9,
#   42,
#   17,
#   83,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-19',
#   'DKI2 (Kelapa Gading)',
#   72,
#   101,
#   55,
#   13,
#   26,
#   36,
#   101,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-20',
#   'DKI2 (Kelapa Gading)',
#   73,
#   97,
#   55,
#   12,
#   34,
#   30,
#   97,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-21',
#   'DKI2 (Kelapa Gading)',
#   60,
#   87,
#   51,
#   10,
#   29,
#   21,
#   87,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-22',
#   'DKI2 (Kelapa Gading)',
#   71,
#   100,
#   52,
#   13,
#   25,
#   26,
#   100,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-23',
#   'DKI2 (Kelapa Gading)',
#   63,
#   86,
#   52,
#   9,
#   33,
#   13,
#   86,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-24',
#   'DKI2 (Kelapa Gading)',
#   69,
#   101,
#   52,
#   9,
#   41,
#   18,
#   101,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-25',
#   'DKI2 (Kelapa Gading)',
#   69,
#   98,
#   51,
#   11,
#   38,
#   24,
#   98,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-26',
#   'DKI2 (Kelapa Gading)',
#   61,
#   84,
#   51,
#   9,
#   26,
#   18,
#   84,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-27',
#   'DKI2 (Kelapa Gading)',
#   63,
#   90,
#   52,
#   10,
#   32,
#   21,
#   90,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-28',
#   'DKI2 (Kelapa Gading)',
#   76,
#   104,
#   51,
#   10,
#   41,
#   22,
#   104,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-29',
#   'DKI2 (Kelapa Gading)',
#   68,
#   97,
#   52,
#   10,
#   30,
#   16,
#   97,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-30',
#   'DKI2 (Kelapa Gading)',
#   79,
#   110,
#   52,
#   12,
#   38,
#   29,
#   110,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-31',
#   'DKI2 (Kelapa Gading)',
#   74,
#   96,
#   51,
#   10,
#   48,
#   19,
#   96,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-01',
#   'DKI3 (Jagakarsa)',
#   51,
#   66,
#   44,
#   9,
#   31,
#   11,
#   66,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-02',
#   'DKI3 (Jagakarsa)',
#   48,
#   65,
#   47,
#   10,
#   29,
#   12,
#   65,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-03',
#   'DKI3 (Jagakarsa)',
#   45,
#   66,
#   48,
#   9,
#   30,
#   13,
#   66,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-04',
#   'DKI3 (Jagakarsa)',
#   56,
#   82,
#   51,
#   8,
#   27,
#   14,
#   82,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-05',
#   'DKI3 (Jagakarsa)',
#   52,
#   82,
#   51,
#   11,
#   23,
#   15,
#   82,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-06',
#   'DKI3 (Jagakarsa)',
#   52,
#   77,
#   42,
#   16,
#   19,
#   18,
#   77,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-07',
#   'DKI3 (Jagakarsa)',
#   59,
#   84,
#   45,
#   10,
#   23,
#   14,
#   84,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-08',
#   'DKI3 (Jagakarsa)',
#   57,
#   84,
#   47,
#   9,
#   26,
#   13,
#   84,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-09',
#   'DKI3 (Jagakarsa)',
#   53,
#   69,
#   45,
#   7,
#   25,
#   10,
#   69,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-10',
#   'DKI3 (Jagakarsa)',
#   36,
#   54,
#   41,
#   6,
#   27,
#   12,
#   54,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-11',
#   'DKI3 (Jagakarsa)',
#   61,
#   88,
#   44,
#   12,
#   30,
#   14,
#   88,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-12',
#   'DKI3 (Jagakarsa)',
#   54,
#   73,
#   46,
#   7,
#   32,
#   11,
#   73,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-13',
#   'DKI3 (Jagakarsa)',
#   61,
#   91,
#   46,
#   11,
#   29,
#   16,
#   91,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-14',
#   'DKI3 (Jagakarsa)',
#   69,
#   102,
#   45,
#   14,
#   29,
#   16,
#   102,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-15',
#   'DKI3 (Jagakarsa)',
#   57,
#   84,
#   45,
#   12,
#   22,
#   15,
#   84,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-16',
#   'DKI3 (Jagakarsa)',
#   53,
#   79,
#   48,
#   9,
#   24,
#   15,
#   79,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-17',
#   'DKI3 (Jagakarsa)',
#   60,
#   88,
#   45,
#   11,
#   30,
#   13,
#   88,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-18',
#   'DKI3 (Jagakarsa)',
#   58,
#   86,
#   43,
#   10,
#   35,
#   11,
#   86,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-19',
#   'DKI3 (Jagakarsa)',
#   68,
#   104,
#   45,
#   14,
#   27,
#   14,
#   104,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-20',
#   'DKI3 (Jagakarsa)',
#   57,
#   83,
#   46,
#   10,
#   29,
#   14,
#   83,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-21',
#   'DKI3 (Jagakarsa)',
#   53,
#   80,
#   44,
#   10,
#   33,
#   15,
#   80,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-22',
#   'DKI3 (Jagakarsa)',
#   58,
#   88,
#   49,
#   14,
#   29,
#   18,
#   88,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-23',
#   'DKI3 (Jagakarsa)',
#   66,
#   100,
#   46,
#   13,
#   31,
#   17,
#   100,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-24',
#   'DKI3 (Jagakarsa)',
#   66,
#   100,
#   46,
#   11,
#   32,
#   15,
#   100,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-25',
#   'DKI3 (Jagakarsa)',
#   57,
#   81,
#   44,
#   10,
#   33,
#   11,
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-26',
#   'DKI3 (Jagakarsa)',
#   54,
#   82,
#   46,
#   9,
#   30,
#   15,
#   82,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-27',
#   'DKI3 (Jagakarsa)',
#   62,
#   92,
#   47,
#   9,
#   31,
#   13,
#   92,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-28',
#   'DKI3 (Jagakarsa)',
#   63,
#   94,
#   46,
#   10,
#   42,
#   17,
#   94,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-29',
#   'DKI3 (Jagakarsa)',
#   67,
#   28,
#   46,
#   12,
#   35,
#   15,
#   67,
#   'PM10',
#   'SEDANG',
#   None),
#  ('2021-08-30',
#   'DKI3 (Jagakarsa)',
#   87,
#   27,
#   46,
#   16,
#   38,
#   17,
#   87,
#   'PM10',
#   'SEDANG',
#   None),
#  ('2021-08-31',
#   'DKI3 (Jagakarsa)',
#   64,
#   27,
#   10,
#   19,
#   38,
#   32,
#   64,
#   'PM10',
#   'SEDANG',
#   None),
#  ('2021-08-01',
#   'DKI4 (Lubang Buaya)',
#   51,
#   86,
#   39,
#   8,
#   30,
#   22,
#   86,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-02',
#   'DKI4 (Lubang Buaya)',
#   42,
#   81,
#   38,
#   9,
#   27,
#   20,
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-03',
#   'DKI4 (Lubang Buaya)',
#   55,
#   104,
#   38,
#   12,
#   21,
#   25,
#   104,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-04',
#   'DKI4 (Lubang Buaya)',
#   51,
#   87,
#   41,
#   7,
#   23,
#   20,
#   87,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-05',
#   'DKI4 (Lubang Buaya)',
#   53,
#   90,
#   38,
#   8,
#   21,
#   19,
#   90,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-06',
#   'DKI4 (Lubang Buaya)',
#   59,
#   105,
#   37,
#   16,
#   13,
#   21,
#   105,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-07',
#   'DKI4 (Lubang Buaya)',
#   59,
#   101,
#   38,
#   8,
#   19,
#   18,
#   101,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-08',
#   'DKI4 (Lubang Buaya)',
#   54,
#   92,
#   40,
#   7,
#   21,
#   17,
#   92,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-09',
#   'DKI4 (Lubang Buaya)',
#   48,
#   82,
#   40,
#   6,
#   26,
#   16,
#   82,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-10',
#   'DKI4 (Lubang Buaya)',
#   35,
#   68,
#   38,
#   6,
#   30,
#   19,
#   68,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-11',
#   'DKI4 (Lubang Buaya)',
#   56,
#   102,
#   39,
#   11,
#   27,
#   23,
#   102,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-12',
#   'DKI4 (Lubang Buaya)',
#   57,
#   104,
#   40,
#   8,
#   21,
#   20,
#   104,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-13',
#   'DKI4 (Lubang Buaya)',
#   55,
#   101,
#   40,
#   11,
#   19,
#   25,
#   101,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-14',
#   'DKI4 (Lubang Buaya)',
#   58,
#   98,
#   41,
#   9,
#   21,
#   21,
#   98,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-15',
#   'DKI4 (Lubang Buaya)',
#   63,
#   114,
#   39,
#   11,
#   15,
#   21,
#   114,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-16',
#   'DKI4 (Lubang Buaya)',
#   55,
#   100,
#   41,
#   8,
#   17,
#   21,
#   100,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-17',
#   'DKI4 (Lubang Buaya)',
#   59,
#   103,
#   41,
#   8,
#   24,
#   20,
#   103,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-18',
#   'DKI4 (Lubang Buaya)',
#   58,
#   97,
#   38,
#   9,
#   30,
#   20,
#   97,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-19',
#   'DKI4 (Lubang Buaya)',
#   67,
#   119,
#   42,
#   13,
#   28,
#   28,
#   119,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-20',
#   'DKI4 (Lubang Buaya)',
#   64,
#   106,
#   40,
#   11,
#   28,
#   23,
#   106,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-21',
#   'DKI4 (Lubang Buaya)',
#   50,
#   85,
#   39,
#   8,
#   25,
#   21,
#   85,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-22',
#   'DKI4 (Lubang Buaya)',
#   74,
#   134,
#   43,
#   14,
#   22,
#   29,
#   134,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-23',
#   'DKI4 (Lubang Buaya)',
#   63,
#   106,
#   40,
#   10,
#   24,
#   20,
#   106,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-24',
#   'DKI4 (Lubang Buaya)',
#   61,
#   110,
#   42,
#   11,
#   26,
#   24,
#   110,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-25',
#   'DKI4 (Lubang Buaya)',
#   62,
#   106,
#   42,
#   9,
#   26,
#   28,
#   106,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-26',
#   'DKI4 (Lubang Buaya)',
#   53,
#   91,
#   40,
#   7,
#   28,
#   19,
#   91,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-27',
#   'DKI4 (Lubang Buaya)',
#   58,
#   105,
#   39,
#   10,
#   28,
#   22,
#   105,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-28',
#   'DKI4 (Lubang Buaya)',
#   65,
#   123,
#   38,
#   10,
#   36,
#   23,
#   123,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-29',
#   'DKI4 (Lubang Buaya)',
#   66,
#   122,
#   39,
#   12,
#   28,
#   25,
#   122,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-30',
#   'DKI4 (Lubang Buaya)',
#   76,
#   140,
#   41,
#   16,
#   30,
#   31,
#   140,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-31',
#   'DKI4 (Lubang Buaya)',
#   61,
#   109,
#   41,
#   10,
#   32,
#   26,
#   109,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-01',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   44,
#   70,
#   30,
#   8,
#   29,
#   11,
#   70,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-02',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   46,
#   75,
#   27,
#   8,
#   27,
#   12,
#   75,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-03',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   53,
#   80,
#   30,
#   9,
#   27,
#   21,
#   80,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-04',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   46,
#   74,
#   33,
#   7,
#   26,
#   18,
#   74,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-05',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   50,
#   78,
#   30,
#   9,
#   17,
#   21,
#   78,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-06',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   57,
#   94,
#   31,
#   20,
#   12,
#   52,
#   94,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-07',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   50,
#   71,
#   37,
#   7,
#   19,
#   18,
#   71,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-08',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   49,
#   73,
#   39,
#   7,
#   23,
#   13,
#   73,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-09',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   45,
#   61,
#   39,
#   4,
#   21,
#   14,
#   61,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-10',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   26,
#   52,
#   27,
#   6,
#   24,
#   14,
#   52,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-11',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   54,
#   92,
#   29,
#   11,
#   25,
#   25,
#   92,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-12',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   54,
#   78,
#   32,
#   7,
#   27,
#   18,
#   78,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-13',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   61,
#   100,
#   33,
#   11,
#   21,
#   32,
#   100,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-14',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   73,
#   116,
#   38,
#   14,
#   26,
#   40,
#   116,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-15',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   62,
#   87,
#   33,
#   12,
#   17,
#   30,
#   87,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-16',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   51,
#   74,
#   35,
#   7,
#   22,
#   20,
#   74,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-17',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   59,
#   89,
#   32,
#   8,
#   26,
#   19,
#   89,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-18',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   62,
#   97,
#   28,
#   9,
#   30,
#   17,
#   97,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-19',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   63,
#   106,
#   38,
#   13,
#   26,
#   33,
#   106,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-20',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   55,
#   81,
#   39,
#   8,
#   34,
#   27,
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-21',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   58,
#   89,
#   32,
#   10,
#   31,
#   24,
#   89,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-22',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   62,
#   94,
#   35,
#   12,
#   24,
#   29,
#   94,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-23',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   59,
#   88,
#   31,
#   9,
#   22,
#   22,
#   88,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-24',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   60,
#   97,
#   31,
#   7,
#   32,
#   12,
#   97,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-25',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   63,
#   95,
#   31,
#   10,
#   29,
#   20,
#   95,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-26',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   64,
#   96,
#   32,
#   9,
#   31,
#   14,
#   96,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-27',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   61,
#   96,
#   34,
#   8,
#   29,
#   15,
#   96,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-28',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   63,
#   100,
#   31,
#   8,
#   44,
#   12,
#   100,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-08-29',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   67,
#   111,
#   32,
#   10,
#   36,
#   13,
#   111,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-30',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   83,
#   126,
#   35,
#   16,
#   32,
#   29,
#   126,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-08-31',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   60,
#   92,
#   30,
#   7,
#   32,
#   14,
#   92,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-01',
#   'DKI1 (Bunderan HI)',
#   '49',
#   '65',
#   '33',
#   '13',
#   '15',
#   '12',
#   '65',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-02',
#   'DKI1 (Bunderan HI)',
#   '28',
#   '34',
#   '31',
#   '7',
#   '15',
#   '5',
#   '34',
#   'PM25',
#   'BAIK',
#   None),
#  ('2021-12-03',
#   'DKI1 (Bunderan HI)',
#   '49',
#   '31',
#   '9',
#   '19',
#   '7',
#   '49',
#   'PM25',
#   'BAIK',
#   None,
#   None),
#  ('2021-12-04',
#   'DKI1 (Bunderan HI)',
#   '39',
#   '52',
#   '35',
#   '13',
#   '15',
#   '9',
#   '52',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-05',
#   'DKI1 (Bunderan HI)',
#   '41',
#   '57',
#   '39',
#   '15',
#   '15',
#   '9',
#   '57',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-06',
#   'DKI1 (Bunderan HI)',
#   '60',
#   '81',
#   '55',
#   '23',
#   '18',
#   '11',
#   '81',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-07',
#   'DKI1 (Bunderan HI)',
#   '30',
#   '31',
#   '34',
#   '12',
#   '16',
#   '9',
#   '34',
#   'SO2',
#   'BAIK',
#   None),
#  ('2021-12-08',
#   'DKI1 (Bunderan HI)',
#   '45',
#   '60',
#   '33',
#   '17',
#   '18',
#   '10',
#   '60',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-09',
#   'DKI1 (Bunderan HI)',
#   '33',
#   '50',
#   '36',
#   '10',
#   '21',
#   '11',
#   '50',
#   'PM25',
#   'BAIK',
#   None),
#  ('2021-12-10',
#   'DKI1 (Bunderan HI)',
#   '46',
#   '59',
#   '43',
#   '14',
#   '19',
#   '12',
#   '59',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-11',
#   'DKI1 (Bunderan HI)',
#   '28',
#   '43',
#   '33',
#   '8',
#   '24',
#   '9',
#   '43',
#   'PM25',
#   'BAIK',
#   None),
#  ('2021-12-12',
#   'DKI1 (Bunderan HI)',
#   '44',
#   '57',
#   '32',
#   '17',
#   '15',
#   '7',
#   '57',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-13',
#   'DKI1 (Bunderan HI)',
#   '31',
#   '46',
#   '34',
#   '10',
#   '13',
#   '6',
#   '46',
#   'PM25',
#   'BAIK',
#   None),
#  ('2021-12-14',
#   'DKI1 (Bunderan HI)',
#   '46',
#   '61',
#   '46',
#   '15',
#   '16',
#   '10',
#   '61',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-15',
#   'DKI1 (Bunderan HI)',
#   '58',
#   '75',
#   '43',
#   '19',
#   '20',
#   '14',
#   '75',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-16',
#   'DKI1 (Bunderan HI)',
#   '56',
#   '74',
#   '39',
#   '20',
#   '24',
#   '16',
#   '74',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-17',
#   'DKI1 (Bunderan HI)',
#   '53',
#   '71',
#   '42',
#   '18',
#   '24',
#   '15',
#   '71',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-18',
#   'DKI1 (Bunderan HI)',
#   '51',
#   '63',
#   '39',
#   '18',
#   '22',
#   '10',
#   '63',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-19',
#   'DKI1 (Bunderan HI)',
#   '58',
#   '81',
#   '38',
#   '24',
#   '33',
#   '15',
#   '81',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-20',
#   'DKI1 (Bunderan HI)',
#   '52',
#   '63',
#   '39',
#   '13',
#   '23',
#   '11',
#   '63',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-21',
#   'DKI1 (Bunderan HI)',
#   '52',
#   '74',
#   '41',
#   '19',
#   '22',
#   '17',
#   '74',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-22',
#   'DKI1 (Bunderan HI)',
#   '63',
#   '85',
#   '56',
#   '28',
#   '25',
#   '19',
#   '85',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-23',
#   'DKI1 (Bunderan HI)',
#   '56',
#   '77',
#   '57',
#   '18',
#   '20',
#   '18',
#   '77',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-24',
#   'DKI1 (Bunderan HI)',
#   '34',
#   '52',
#   '53',
#   '15',
#   '17',
#   '11',
#   '53',
#   'SO2',
#   'SEDANG',
#   None),
#  ('2021-12-25',
#   'DKI1 (Bunderan HI)',
#   '53',
#   '68',
#   '56',
#   '17',
#   '17',
#   '9',
#   '68',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-26',
#   'DKI1 (Bunderan HI)',
#   '35',
#   '53',
#   '51',
#   '11',
#   '22',
#   '10',
#   '53',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-27',
#   'DKI1 (Bunderan HI)',
#   '52',
#   '71',
#   '61',
#   '15',
#   '20',
#   '15',
#   '71',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-28',
#   'DKI1 (Bunderan HI)',
#   '51',
#   '65',
#   '53',
#   '15',
#   '18',
#   '13',
#   '65',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-29',
#   'DKI1 (Bunderan HI)',
#   '31',
#   '49',
#   '54',
#   '10',
#   '24',
#   '11',
#   '54',
#   'SO2',
#   'SEDANG',
#   None),
#  ('2021-12-30',
#   'DKI1 (Bunderan HI)',
#   '55',
#   '71',
#   '53',
#   '16',
#   '23',
#   '14',
#   '71',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-31',
#   'DKI1 (Bunderan HI)',
#   '62',
#   '85',
#   '52',
#   '23',
#   '20',
#   '14',
#   '85',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-01',
#   'DKI2 (Kelapa Gading)',
#   '53',
#   '---',
#   '8',
#   '12',
#   '41',
#   '30',
#   '53',
#   'PM10',
#   'SEDANG',
#   None),
#  ('2021-12-02',
#   'DKI2 (Kelapa Gading)',
#   '32',
#   '50',
#   '40',
#   '7',
#   '40',
#   '14',
#   '50',
#   'PM25',
#   'BAIK',
#   None),
#  ('2021-12-03',
#   'DKI2 (Kelapa Gading)',
#   '34',
#   '55',
#   '41',
#   '9',
#   '48',
#   '17',
#   '55',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-04',
#   'DKI2 (Kelapa Gading)',
#   '40',
#   '63',
#   '43',
#   '8',
#   '43',
#   '16',
#   '63',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-05',
#   'DKI2 (Kelapa Gading)',
#   '46',
#   '65',
#   '44',
#   '14',
#   '39',
#   '24',
#   '65',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-06',
#   'DKI2 (Kelapa Gading)',
#   '61',
#   '88',
#   '51',
#   '18',
#   '45',
#   '31',
#   '88',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-07',
#   'DKI2 (Kelapa Gading)',
#   '33',
#   '58',
#   '42',
#   '11',
#   '43',
#   '19',
#   '58',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-08',
#   'DKI2 (Kelapa Gading)',
#   '49',
#   '71',
#   '31',
#   '15',
#   '51',
#   '30',
#   '71',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-09',
#   'DKI2 (Kelapa Gading)',
#   '31',
#   '52',
#   '32',
#   '8',
#   '50',
#   '20',
#   '52',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-10',
#   'DKI2 (Kelapa Gading)',
#   '33',
#   '54',
#   '34',
#   '9',
#   '41',
#   '24',
#   '54',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-11',
#   'DKI2 (Kelapa Gading)',
#   '33',
#   '50',
#   '33',
#   '8',
#   '51',
#   '22',
#   '51',
#   'O3',
#   'SEDANG',
#   None),
#  ('2021-12-12',
#   'DKI2 (Kelapa Gading)',
#   '49',
#   '62',
#   '40',
#   '13',
#   '42',
#   '22',
#   '62',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-13',
#   'DKI2 (Kelapa Gading)',
#   '31',
#   '53',
#   '34',
#   '9',
#   '34',
#   '23',
#   '53',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-14',
#   'DKI2 (Kelapa Gading)',
#   '51',
#   '65',
#   '43',
#   '9',
#   '35',
#   '26',
#   '65',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-15',
#   'DKI2 (Kelapa Gading)',
#   '62',
#   '86',
#   '44',
#   '11',
#   '50',
#   '30',
#   '86',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-16',
#   'DKI2 (Kelapa Gading)',
#   '---',
#   '---',
#   '---',
#   '---',
#   '---',
#   '---',
#   '0',
#   None,
#   'TIDAK ADA DATA',
#   None),
#  ('2021-12-17',
#   'DKI2 (Kelapa Gading)',
#   '58',
#   '75',
#   '35',
#   '15',
#   '57',
#   '32',
#   '75',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-18',
#   'DKI2 (Kelapa Gading)',
#   '44',
#   '64',
#   '35',
#   '13',
#   '54',
#   '24',
#   '64',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-19',
#   'DKI2 (Kelapa Gading)',
#   '65',
#   '96',
#   '40',
#   '21',
#   '78',
#   '33',
#   '96',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-20',
#   'DKI2 (Kelapa Gading)',
#   '53',
#   '67',
#   '32',
#   '11',
#   '58',
#   '20',
#   '67',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-21',
#   'DKI2 (Kelapa Gading)',
#   '55',
#   '74',
#   '40',
#   '15',
#   '---',
#   '33',
#   '74',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-22',
#   'DKI2 (Kelapa Gading)',
#   '65',
#   '94',
#   '36',
#   '21',
#   '54',
#   '49',
#   '94',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-23',
#   'DKI2 (Kelapa Gading)',
#   '70',
#   '99',
#   '46',
#   '19',
#   '42',
#   '42',
#   '99',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-24',
#   'DKI2 (Kelapa Gading)',
#   '36',
#   '56',
#   '35',
#   '15',
#   '36',
#   '27',
#   '56',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-25',
#   'DKI2 (Kelapa Gading)',
#   '53',
#   '70',
#   '38',
#   '19',
#   '35',
#   '30',
#   '70',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-26',
#   'DKI2 (Kelapa Gading)',
#   '41',
#   '55',
#   '38',
#   '15',
#   '37',
#   '24',
#   '55',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-27',
#   'DKI2 (Kelapa Gading)',
#   '50',
#   '66',
#   '35',
#   '14',
#   '40',
#   '24',
#   '66',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-28',
#   'DKI2 (Kelapa Gading)',
#   '53',
#   '68',
#   '38',
#   '16',
#   '34',
#   '33',
#   '68',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-29',
#   'DKI2 (Kelapa Gading)',
#   '28',
#   '---',
#   '32',
#   '12',
#   '37',
#   '29',
#   '37',
#   'O3',
#   'BAIK',
#   None),
#  ('2021-12-30',
#   'DKI2 (Kelapa Gading)',
#   '47',
#   '64',
#   '38',
#   '13',
#   '38',
#   '35',
#   '64',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-31',
#   'DKI2 (Kelapa Gading)',
#   '61',
#   '85',
#   '33',
#   '23',
#   '37',
#   '44',
#   '85',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-01',
#   'DKI3 (Jagakarsa)',
#   '53',
#   '70',
#   '43',
#   '12',
#   '32',
#   '15',
#   '70',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-02',
#   'DKI3 (Jagakarsa)',
#   '35',
#   '55',
#   '42',
#   '7',
#   '29',
#   '9',
#   '55',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-03',
#   'DKI3 (Jagakarsa)',
#   '54',
#   '67',
#   '43',
#   '9',
#   '32',
#   '11',
#   '67',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-04',
#   'DKI3 (Jagakarsa)',
#   '50',
#   '65',
#   '45',
#   '10',
#   '26',
#   '13',
#   '65',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-05',
#   'DKI3 (Jagakarsa)',
#   '51',
#   '66',
#   '43',
#   '15',
#   '27',
#   '12',
#   '66',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-06',
#   'DKI3 (Jagakarsa)',
#   '62',
#   '91',
#   '47',
#   '17',
#   '42',
#   '18',
#   '91',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-07',
#   'DKI3 (Jagakarsa)',
#   '20',
#   '28',
#   '44',
#   '7',
#   '32',
#   '10',
#   '44',
#   'SO2',
#   'BAIK',
#   None),
#  ('2021-12-08',
#   'DKI3 (Jagakarsa)',
#   '39',
#   '62',
#   '45',
#   '17',
#   '45',
#   '13',
#   '62',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-09',
#   'DKI3 (Jagakarsa)',
#   '46',
#   '60',
#   '46',
#   '11',
#   '51',
#   '16',
#   '60',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-10',
#   'DKI3 (Jagakarsa)',
#   '51',
#   '65',
#   '47',
#   '12',
#   '---',
#   '15',
#   '65',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-11',
#   'DKI3 (Jagakarsa)',
#   '38',
#   '55',
#   '45',
#   '8',
#   '47',
#   '12',
#   '55',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-12',
#   'DKI3 (Jagakarsa)',
#   '48',
#   '63',
#   '43',
#   '13',
#   '---',
#   '13',
#   '63',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-13',
#   'DKI3 (Jagakarsa)',
#   '53',
#   '68',
#   '44',
#   '11',
#   '23',
#   '10',
#   '68',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-14',
#   'DKI3 (Jagakarsa)',
#   '40',
#   '---',
#   '44',
#   '7',
#   '37',
#   '11',
#   '44',
#   'SO2',
#   'BAIK',
#   None),
#  ('2021-12-15',
#   'DKI3 (Jagakarsa)',
#   '54',
#   '80',
#   '43',
#   '16',
#   '---',
#   '16',
#   '80',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-16',
#   'DKI3 (Jagakarsa)',
#   '47',
#   '68',
#   '43',
#   '11',
#   '---',
#   '15',
#   '68',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-17',
#   'DKI3 (Jagakarsa)',
#   '39',
#   '59',
#   '43',
#   '13',
#   '---',
#   '16',
#   '59',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-18',
#   'DKI3 (Jagakarsa)',
#   '35',
#   '58',
#   '35',
#   '10',
#   '33',
#   '12',
#   '58',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-19',
#   'DKI3 (Jagakarsa)',
#   '57',
#   '90',
#   '34',
#   '20',
#   '48',
#   '23',
#   '90',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-20',
#   'DKI3 (Jagakarsa)',
#   '54',
#   '74',
#   '34',
#   '13',
#   '43',
#   '15',
#   '74',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-21',
#   'DKI3 (Jagakarsa)',
#   '49',
#   '72',
#   '34',
#   '14',
#   '39',
#   '18',
#   '72',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-22',
#   'DKI3 (Jagakarsa)',
#   '56',
#   '82',
#   '34',
#   '21',
#   '44',
#   '24',
#   '82',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-23',
#   'DKI3 (Jagakarsa)',
#   '56',
#   '78',
#   '34',
#   '12',
#   '44',
#   '17',
#   '78',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-24',
#   'DKI3 (Jagakarsa)',
#   '33',
#   '53',
#   '34',
#   '9',
#   '31',
#   '10',
#   '53',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-25',
#   'DKI3 (Jagakarsa)',
#   '54',
#   '77',
#   '33',
#   '18',
#   '31',
#   '13',
#   '77',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-26',
#   'DKI3 (Jagakarsa)',
#   '39',
#   '59',
#   '33',
#   '14',
#   '36',
#   '12',
#   '59',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-27',
#   'DKI3 (Jagakarsa)',
#   '75',
#   '116',
#   '35',
#   '23',
#   '38',
#   '21',
#   '116',
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-12-28',
#   'DKI3 (Jagakarsa)',
#   '51',
#   '74',
#   '---',
#   '13',
#   '17',
#   '18',
#   '74',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-29',
#   'DKI3 (Jagakarsa)',
#   '47',
#   '54',
#   '21',
#   '12',
#   '20',
#   '9',
#   '54',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-30',
#   'DKI3 (Jagakarsa)',
#   '60',
#   '53',
#   '21',
#   '15',
#   '19',
#   '13',
#   '60',
#   'PM10',
#   'SEDANG',
#   None),
#  ('2021-12-31',
#   'DKI3 (Jagakarsa)',
#   '64',
#   '52',
#   '21',
#   '44',
#   '17',
#   '---',
#   '64',
#   'PM10',
#   'SEDANG',
#   None),
#  ('2021-12-01',
#   'DKI4 (Lubang Buaya)',
#   '63',
#   '100',
#   '39',
#   '12',
#   '19',
#   '23',
#   '100',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-02',
#   'DKI4 (Lubang Buaya)',
#   '33',
#   '56',
#   '38',
#   '5',
#   '18',
#   '13',
#   '56',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-03',
#   'DKI4 (Lubang Buaya)',
#   '41',
#   '71',
#   '39',
#   '7',
#   '23',
#   '15',
#   '71',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-04',
#   'DKI4 (Lubang Buaya)',
#   '42',
#   '62',
#   '39',
#   '8',
#   '14',
#   '15',
#   '62',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-05',
#   'DKI4 (Lubang Buaya)',
#   '53',
#   '80',
#   '39',
#   '17',
#   '13',
#   '15',
#   '80',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-06',
#   'DKI4 (Lubang Buaya)',
#   '52',
#   '83',
#   '41',
#   '20',
#   '23',
#   '19',
#   '83',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-07',
#   'DKI4 (Lubang Buaya)',
#   '179',
#   '58',
#   '39',
#   '9',
#   '17',
#   '15',
#   '179',
#   'PM10',
#   'TIDAK SEHAT',
#   None),
#  ('2021-12-08',
#   'DKI4 (Lubang Buaya)',
#   '47',
#   '76',
#   '40',
#   '14',
#   '25',
#   '14',
#   '76',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-09',
#   'DKI4 (Lubang Buaya)',
#   '38',
#   '63',
#   '40',
#   '9',
#   '28',
#   '19',
#   '63',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-10',
#   'DKI4 (Lubang Buaya)',
#   '45',
#   '73',
#   '42',
#   '10',
#   '24',
#   '19',
#   '73',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-11',
#   'DKI4 (Lubang Buaya)',
#   '32',
#   '60',
#   '39',
#   '7',
#   '22',
#   '17',
#   '60',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-12',
#   'DKI4 (Lubang Buaya)',
#   '---',
#   '---',
#   '---',
#   '---',
#   '---',
#   '---',
#   '0',
#   None,
#   'TIDAK ADA DATA',
#   None),
#  ('2021-12-13',
#   'DKI4 (Lubang Buaya)',
#   '---',
#   '---',
#   '---',
#   '---',
#   '---',
#   '---',
#   '0',
#   None,
#   'TIDAK ADA DATA',
#   None),
#  ('2021-12-14',
#   'DKI4 (Lubang Buaya)',
#   '50',
#   '76',
#   '40',
#   '7',
#   '28',
#   '14',
#   '76',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-15',
#   'DKI4 (Lubang Buaya)',
#   '69',
#   '124',
#   '40',
#   '15',
#   '29',
#   '23',
#   '124',
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-12-16',
#   'DKI4 (Lubang Buaya)',
#   '78',
#   '136',
#   '41',
#   '14',
#   '32',
#   '18',
#   '136',
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-12-17',
#   'DKI4 (Lubang Buaya)',
#   '55',
#   '81',
#   '39',
#   '13',
#   '34',
#   '17',
#   '81',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-18',
#   'DKI4 (Lubang Buaya)',
#   '---',
#   '69',
#   '42',
#   '13',
#   '24',
#   '17',
#   '69',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-19',
#   'DKI4 (Lubang Buaya)',
#   '64',
#   '102',
#   '41',
#   '21',
#   '40',
#   '22',
#   '102',
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-12-20',
#   'DKI4 (Lubang Buaya)',
#   '57',
#   '86',
#   '42',
#   '10',
#   '30',
#   '16',
#   '86',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-21',
#   'DKI4 (Lubang Buaya)',
#   '62',
#   '---',
#   '42',
#   '17',
#   '13',
#   '27',
#   '62',
#   'PM10',
#   'SEDANG',
#   None),
#  ('2021-12-22',
#   'DKI4 (Lubang Buaya)',
#   '62',
#   '98',
#   '27',
#   '22',
#   '---',
#   '34',
#   '98',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-23',
#   'DKI4 (Lubang Buaya)',
#   '62',
#   '99',
#   '26',
#   '13',
#   '---',
#   '26',
#   '99',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-24',
#   'DKI4 (Lubang Buaya)',
#   '34',
#   '65',
#   '---',
#   '---',
#   '---',
#   '---',
#   '65',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-25',
#   'DKI4 (Lubang Buaya)',
#   '56',
#   '85',
#   '15',
#   '23',
#   '---',
#   '---',
#   '85',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-26',
#   'DKI4 (Lubang Buaya)',
#   '44',
#   '71',
#   '13',
#   '14',
#   '---',
#   '8',
#   '71',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-27',
#   'DKI4 (Lubang Buaya)',
#   '68',
#   '121',
#   '17',
#   '21',
#   '---',
#   '12',
#   '121',
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-12-28',
#   'DKI4 (Lubang Buaya)',
#   '59',
#   '89',
#   '38',
#   '15',
#   '---',
#   '22',
#   '89',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-29',
#   'DKI4 (Lubang Buaya)',
#   '61',
#   '98',
#   '37',
#   '15',
#   '---',
#   '19',
#   '98',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-30',
#   'DKI4 (Lubang Buaya)',
#   '60',
#   '102',
#   '38',
#   '17',
#   '---',
#   '21',
#   '102',
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-12-31',
#   'DKI4 (Lubang Buaya)',
#   '58',
#   '90',
#   '36',
#   '21',
#   '---',
#   '22',
#   '90',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-01',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '50',
#   '71',
#   '18',
#   '8',
#   '19',
#   '18',
#   '71',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-02',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '22',
#   '42',
#   '14',
#   '2',
#   '19',
#   '5',
#   '42',
#   'PM25',
#   'BAIK',
#   None),
#  ('2021-12-03',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '30',
#   '54',
#   '16',
#   '3',
#   '18',
#   '9',
#   '54',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-04',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '34',
#   '54',
#   '27',
#   '5',
#   '14',
#   '15',
#   '54',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-05',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '51',
#   '71',
#   '30',
#   '12',
#   '12',
#   '29',
#   '71',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-06',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '61',
#   '85',
#   '36',
#   '23',
#   '18',
#   '57',
#   '85',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-07',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '25',
#   '44',
#   '22',
#   '5',
#   '15',
#   '21',
#   '44',
#   'PM25',
#   'BAIK',
#   None),
#  ('2021-12-08',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '44',
#   '66',
#   '17',
#   '13',
#   '23',
#   '30',
#   '66',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-09',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '30',
#   '50',
#   '20',
#   '5',
#   '31',
#   '15',
#   '50',
#   'PM25',
#   'BAIK',
#   None),
#  ('2021-12-10',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '48',
#   '63',
#   '32',
#   '8',
#   '28',
#   '30',
#   '63',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-11',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '32',
#   '54',
#   '21',
#   '5',
#   '31',
#   '15',
#   '54',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-12',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '39',
#   '60',
#   '16',
#   '13',
#   '20',
#   '34',
#   '60',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-13',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '22',
#   '45',
#   '20',
#   '3',
#   '16',
#   '14',
#   '45',
#   'PM25',
#   'BAIK',
#   None),
#  ('2021-12-14',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '36',
#   '56',
#   '33',
#   '3',
#   '21',
#   '21',
#   '56',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-15',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '51',
#   '67',
#   '32',
#   '5',
#   '31',
#   '28',
#   '67',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-16',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '56',
#   '82',
#   '23',
#   '11',
#   '34',
#   '36',
#   '82',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-17',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '52',
#   '73',
#   '26',
#   '8',
#   '28',
#   '35',
#   '73',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-18',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '45',
#   '63',
#   '18',
#   '8',
#   '22',
#   '32',
#   '63',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-19',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '54',
#   '84',
#   '19',
#   '18',
#   '35',
#   '45',
#   '84',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-20',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '48',
#   '65',
#   '20',
#   '6',
#   '22',
#   '16',
#   '65',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-21',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '47',
#   '73',
#   '20',
#   '15',
#   '31',
#   '49',
#   '73',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-22',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '62',
#   '90',
#   '19',
#   '24',
#   '29',
#   '65',
#   '90',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-23',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '59',
#   '88',
#   '24',
#   '16',
#   '23',
#   '44',
#   '88',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-24',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '32',
#   '59',
#   '25',
#   '9',
#   '19',
#   '52',
#   '59',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-25',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '55',
#   '81',
#   '34',
#   '17',
#   '15',
#   '62',
#   '81',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-26',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '32',
#   '57',
#   '27',
#   '9',
#   '20',
#   '34',
#   '57',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-27',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '54',
#   '76',
#   '36',
#   '14',
#   '21',
#   '47',
#   '76',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-28',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '44',
#   '68',
#   '20',
#   '11',
#   '21',
#   '33',
#   '68',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-29',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '34',
#   '54',
#   '28',
#   '8',
#   '25',
#   '29',
#   '54',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-30',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '53',
#   '75',
#   '25',
#   '15',
#   '23',
#   '44',
#   '75',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-12-31',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '60',
#   '87',
#   '28',
#   '19',
#   '30',
#   '53',
#   '87',
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-07-01',
#   None,
#   'DKI1 (Bunderan HI)',
#   '55',
#   '76',
#   '27',
#   '14',
#   '20',
#   '31',
#   76,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-02',
#   None,
#   'DKI1 (Bunderan HI)',
#   '55',
#   '70',
#   '33',
#   '16',
#   '14',
#   '30',
#   70,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-03',
#   None,
#   'DKI1 (Bunderan HI)',
#   '58',
#   '81',
#   '33',
#   '12',
#   '19',
#   '25',
#   81,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-04',
#   None,
#   'DKI1 (Bunderan HI)',
#   '68',
#   '102',
#   '27',
#   '11',
#   '27',
#   '22',
#   102,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-05',
#   None,
#   'DKI1 (Bunderan HI)',
#   '71',
#   '106',
#   '28',
#   '12',
#   '34',
#   '25',
#   106,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-06',
#   None,
#   'DKI1 (Bunderan HI)',
#   '56',
#   '74',
#   '26',
#   '9',
#   '29',
#   '29',
#   74,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-07',
#   None,
#   'DKI1 (Bunderan HI)',
#   '64',
#   '86',
#   '34',
#   '10',
#   '22',
#   '27',
#   86,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-08',
#   None,
#   'DKI1 (Bunderan HI)',
#   '68',
#   '94',
#   '32',
#   '10',
#   '26',
#   '26',
#   94,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-09',
#   None,
#   'DKI1 (Bunderan HI)',
#   '70',
#   '101',
#   '33',
#   '9',
#   '28',
#   '25',
#   101,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-10',
#   None,
#   'DKI1 (Bunderan HI)',
#   '64',
#   '83',
#   '35',
#   '7',
#   '24',
#   '23',
#   83,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-11',
#   None,
#   'DKI1 (Bunderan HI)',
#   '54',
#   '71',
#   '32',
#   '6',
#   '21',
#   '15',
#   71,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-12',
#   None,
#   'DKI1 (Bunderan HI)',
#   '46',
#   '59',
#   '29',
#   '5',
#   '18',
#   '13',
#   59,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-13',
#   None,
#   'DKI1 (Bunderan HI)',
#   '63',
#   '89',
#   '33',
#   '10',
#   '18',
#   '24',
#   89,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-14',
#   None,
#   'DKI1 (Bunderan HI)',
#   '53',
#   '69',
#   '28',
#   '10',
#   '17',
#   '23',
#   69,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-15',
#   None,
#   'DKI1 (Bunderan HI)',
#   '66',
#   '95',
#   '31',
#   '12',
#   '24',
#   '30',
#   95,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-16',
#   None,
#   'DKI1 (Bunderan HI)',
#   '71',
#   '97',
#   '30',
#   '11',
#   '24',
#   '29',
#   97,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-17',
#   None,
#   'DKI1 (Bunderan HI)',
#   '63',
#   '80',
#   '29',
#   '8',
#   '28',
#   '20',
#   80,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-18',
#   None,
#   'DKI1 (Bunderan HI)',
#   '63',
#   '89',
#   '31',
#   '8',
#   '32',
#   '19',
#   89,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-19',
#   None,
#   'DKI1 (Bunderan HI)',
#   '66',
#   '95',
#   '26',
#   '10',
#   '32',
#   '28',
#   95,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-20',
#   None,
#   'DKI1 (Bunderan HI)',
#   '74',
#   '100',
#   '27',
#   '15',
#   '24',
#   '24',
#   100,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-21',
#   None,
#   'DKI1 (Bunderan HI)',
#   '48',
#   '66',
#   '27',
#   '7',
#   '26',
#   '17',
#   66,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-22',
#   None,
#   'DKI1 (Bunderan HI)',
#   '53',
#   '76',
#   '31',
#   '9',
#   '24',
#   '26',
#   76,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-23',
#   None,
#   'DKI1 (Bunderan HI)',
#   '58',
#   '80',
#   '26',
#   '9',
#   '27',
#   '28',
#   80,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-24',
#   None,
#   'DKI1 (Bunderan HI)',
#   '53',
#   '79',
#   '26',
#   '13',
#   '21',
#   '34',
#   79,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-25',
#   None,
#   'DKI1 (Bunderan HI)',
#   '70',
#   '108',
#   '25',
#   '23',
#   '28',
#   '38',
#   108,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-26',
#   None,
#   'DKI1 (Bunderan HI)',
#   '65',
#   '95',
#   '27',
#   '14',
#   '17',
#   '32',
#   95,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-27',
#   None,
#   'DKI1 (Bunderan HI)',
#   '61',
#   '91',
#   '29',
#   '10',
#   '23',
#   '28',
#   91,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-28',
#   None,
#   'DKI1 (Bunderan HI)',
#   '68',
#   '102',
#   '31',
#   '13',
#   '20',
#   '30',
#   102,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-29',
#   None,
#   'DKI1 (Bunderan HI)',
#   '59',
#   '85',
#   '28',
#   '13',
#   '24',
#   '32',
#   85,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-30',
#   None,
#   'DKI1 (Bunderan HI)',
#   '73',
#   '105',
#   '29',
#   '12',
#   '39',
#   '35',
#   105,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-31',
#   None,
#   'DKI1 (Bunderan HI)',
#   '54',
#   '72',
#   '26',
#   '7',
#   '27',
#   '24',
#   72,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-01',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '64',
#   '81',
#   '53',
#   '12',
#   '48',
#   '28',
#   81,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-02',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '68',
#   '81',
#   '56',
#   '14',
#   '40',
#   '27',
#   81,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-03',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '72',
#   '100',
#   '54',
#   '11',
#   '44',
#   '23',
#   100,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-04',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '94',
#   '129',
#   '51',
#   '15',
#   '50',
#   '23',
#   129,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-05',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '77',
#   '111',
#   '56',
#   '12',
#   '62',
#   '20',
#   111,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-06',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '64',
#   '79',
#   '51',
#   '10',
#   '55',
#   '17',
#   79,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-07',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '84',
#   '108',
#   '54',
#   '11',
#   '51',
#   '23',
#   108,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-08',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '83',
#   '111',
#   '56',
#   '11',
#   '50',
#   '24',
#   111,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-09',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '92',
#   '120',
#   '59',
#   '11',
#   '56',
#   '26',
#   120,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-10',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '78',
#   '104',
#   '54',
#   '10',
#   '63',
#   '17',
#   104,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-11',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '---',
#   '---',
#   '54',
#   '10',
#   '54',
#   '13',
#   54,
#   'SO2',
#   'SEDANG'),
#  ('2021-07-12',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '64',
#   '---',
#   '52',
#   '9',
#   '44',
#   '13',
#   64,
#   'PM10',
#   'SEDANG'),
#  ('2021-07-13',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '78',
#   '119',
#   '54',
#   '11',
#   '43',
#   '23',
#   119,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-14',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '56',
#   '75',
#   '51',
#   '12',
#   '50',
#   '23',
#   75,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-15',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '79',
#   '111',
#   '62',
#   '11',
#   '56',
#   '26',
#   111,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-16',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '85',
#   '115',
#   '53',
#   '11',
#   '53',
#   '19',
#   115,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-17',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '74',
#   '99',
#   '55',
#   '10',
#   '58',
#   '20',
#   99,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-18',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '82',
#   '114',
#   '55',
#   '11',
#   '58',
#   '17',
#   114,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-19',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '74',
#   '100',
#   '51',
#   '10',
#   '77',
#   '13',
#   100,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-20',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '86',
#   '113',
#   '51',
#   '14',
#   '60',
#   '19',
#   113,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-21',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '54',
#   '72',
#   '52',
#   '9',
#   '58',
#   '13',
#   72,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-22',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '60',
#   '82',
#   '53',
#   '11',
#   '54',
#   '22',
#   82,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-23',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '61',
#   '---',
#   '52',
#   '9',
#   '59',
#   '20',
#   61,
#   'PM10',
#   'SEDANG'),
#  ('2021-07-24',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '66',
#   '95',
#   '54',
#   '13',
#   '51',
#   '30',
#   95,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-25',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '81',
#   '112',
#   '55',
#   '16',
#   '54',
#   '28',
#   112,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-26',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '79',
#   '109',
#   '54',
#   '12',
#   '46',
#   '22',
#   109,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-27',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '82',
#   '112',
#   '56',
#   '12',
#   '41',
#   '27',
#   112,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-28',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '82',
#   '113',
#   '53',
#   '13',
#   '40',
#   '28',
#   113,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-29',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '69',
#   '97',
#   '52',
#   '12',
#   '53',
#   '24',
#   97,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-30',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '90',
#   '117',
#   '54',
#   '12',
#   '81',
#   '29',
#   117,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-31',
#   None,
#   'DKI2 (Kelapa Gading)',
#   '63',
#   '---',
#   '50',
#   '8',
#   '65',
#   '18',
#   65,
#   'O3',
#   'SEDANG'),
#  ('2021-07-01',
#   None,
#   'DKI3 (Jagakarsa)',
#   '64',
#   '92',
#   '48',
#   '8',
#   '22',
#   '18',
#   92,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-02',
#   None,
#   'DKI3 (Jagakarsa)',
#   '60',
#   '84',
#   '47',
#   '7',
#   '23',
#   '18',
#   84,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-03',
#   None,
#   'DKI3 (Jagakarsa)',
#   '80',
#   '124',
#   '45',
#   '10',
#   '28',
#   '17',
#   124,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-04',
#   None,
#   'DKI3 (Jagakarsa)',
#   '86',
#   '132',
#   '44',
#   '9',
#   '28',
#   '14',
#   132,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-05',
#   None,
#   'DKI3 (Jagakarsa)',
#   '67',
#   '105',
#   '46',
#   '7',
#   '38',
#   '15',
#   105,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-06',
#   None,
#   'DKI3 (Jagakarsa)',
#   '68',
#   '102',
#   '44',
#   '7',
#   '32',
#   '16',
#   102,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-07',
#   None,
#   'DKI3 (Jagakarsa)',
#   '73',
#   '109',
#   '48',
#   '8',
#   '31',
#   '17',
#   109,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-08',
#   None,
#   'DKI3 (Jagakarsa)',
#   '71',
#   '110',
#   '50',
#   '6',
#   '33',
#   '16',
#   110,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-09',
#   None,
#   'DKI3 (Jagakarsa)',
#   '79',
#   '119',
#   '51',
#   '7',
#   '34',
#   '17',
#   119,
#   'PM25',
#   'TIDAK SEHAT'),
#  ('2021-07-10',
#   None,
#   'DKI3 (Jagakarsa)',
#   '67',
#   '97',
#   '51',
#   '4',
#   '31',
#   '14',
#   97,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-11',
#   None,
#   'DKI3 (Jagakarsa)',
#   '60',
#   '80',
#   '47',
#   '5',
#   '21',
#   '14',
#   80,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-12',
#   None,
#   'DKI3 (Jagakarsa)',
#   '50',
#   '---',
#   '47',
#   '4',
#   '14',
#   '11',
#   50,
#   'PM10',
#   'BAIK'),
#  ('2021-07-13',
#   None,
#   'DKI3 (Jagakarsa)',
#   '62',
#   '99',
#   '50',
#   '8',
#   '25',
#   '18',
#   99,
#   'PM25',
#   'SEDANG'),
#  ('2021-07-14',
#   None,
#   'DKI3 (Jagakarsa)',
#   '66',
#   '94',
#   '45',
#   '6',
#   '23',
#   '15',
#   94,
#   'PM25',
# ...
#   '41',
#   '18',
#   '31',
#   '23',
#   80,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-20',
#   'DKI4 (Lubang Buaya)',
#   '---',
#   '96',
#   '45',
#   '10',
#   '33',
#   '17',
#   96,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-21',
#   'DKI4 (Lubang Buaya)',
#   '---',
#   '---',
#   '44',
#   '10',
#   '48',
#   '18',
#   48,
#   'O3',
#   'BAIK',
#   None),
#  ('2021-10-22',
#   'DKI4 (Lubang Buaya)',
#   '71',
#   '120',
#   '45',
#   '13',
#   '36',
#   '21',
#   120,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-10-23',
#   'DKI4 (Lubang Buaya)',
#   '65',
#   '109',
#   '45',
#   '10',
#   '35',
#   '20',
#   109,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-10-24',
#   'DKI4 (Lubang Buaya)',
#   '68',
#   '113',
#   '44',
#   '15',
#   '39',
#   '23',
#   113,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-10-25',
#   'DKI4 (Lubang Buaya)',
#   '62',
#   '104',
#   '44',
#   '11',
#   '41',
#   '22',
#   104,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-10-26',
#   'DKI4 (Lubang Buaya)',
#   '75',
#   '130',
#   '45',
#   '16',
#   '36',
#   '24',
#   130,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-10-27',
#   'DKI4 (Lubang Buaya)',
#   '59',
#   '90',
#   '43',
#   '10',
#   '50',
#   '21',
#   90,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-28',
#   'DKI4 (Lubang Buaya)',
#   '54',
#   '78',
#   '40',
#   '11',
#   '56',
#   '18',
#   78,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-29',
#   'DKI4 (Lubang Buaya)',
#   '51',
#   '79',
#   '41',
#   '15',
#   '45',
#   '15',
#   79,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-30',
#   'DKI4 (Lubang Buaya)',
#   '62',
#   '103',
#   '43',
#   '15',
#   '58',
#   '18',
#   103,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-10-31',
#   'DKI4 (Lubang Buaya)',
#   '---',
#   '79',
#   '---',
#   '---',
#   '---',
#   '---',
#   79,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-01',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '55',
#   '84',
#   '---',
#   '8',
#   '34',
#   '12',
#   84,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-02',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '67',
#   '102',
#   '---',
#   '10',
#   '31',
#   '16',
#   102,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-10-03',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '55',
#   '82',
#   '---',
#   '8',
#   '28',
#   '12',
#   82,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-04',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '53',
#   '80',
#   '---',
#   '7',
#   '31',
#   '10',
#   80,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-05',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '52',
#   '79',
#   '---',
#   '10',
#   '35',
#   '16',
#   79,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-06',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '52',
#   '74',
#   '---',
#   '6',
#   '28',
#   '14',
#   74,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-07',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '50',
#   '71',
#   '---',
#   '8',
#   '25',
#   '17',
#   71,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-08',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '53',
#   '81',
#   '---',
#   '7',
#   '32',
#   '16',
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-09',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '53',
#   '74',
#   '---',
#   '7',
#   '43',
#   '12',
#   74,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-10',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '55',
#   '80',
#   '---',
#   '8',
#   '46',
#   '11',
#   80,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-11',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '59',
#   '88',
#   '---',
#   '9',
#   '39',
#   '11',
#   88,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-12',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '57',
#   '81',
#   '---',
#   '12',
#   '31',
#   '23',
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-13',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '47',
#   '69',
#   '---',
#   '7',
#   '30',
#   '13',
#   69,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-14',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '58',
#   '91',
#   '---',
#   '10',
#   '35',
#   '14',
#   91,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-15',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '70',
#   '107',
#   '---',
#   '11',
#   '39',
#   '16',
#   107,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-10-16',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '68',
#   '112',
#   '---',
#   '14',
#   '32',
#   '17',
#   112,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-10-17',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '62',
#   '100',
#   '---',
#   '11',
#   '48',
#   '10',
#   100,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-18',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '52',
#   '73',
#   '---',
#   '11',
#   '19',
#   '15',
#   73,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-19',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '50',
#   '81',
#   '---',
#   '16',
#   '13',
#   '35',
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-20',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '42',
#   '68',
#   '---',
#   '11',
#   '22',
#   '23',
#   68,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-21',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '42',
#   '70',
#   '---',
#   '7',
#   '34',
#   '14',
#   70,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-22',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '60',
#   '95',
#   '---',
#   '15',
#   '24',
#   '26',
#   95,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-23',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '52',
#   '80',
#   '---',
#   '10',
#   '29',
#   '16',
#   80,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-24',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '60',
#   '93',
#   '---',
#   '12',
#   '35',
#   '14',
#   93,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-25',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '64',
#   '101',
#   '---',
#   '13',
#   '36',
#   '14',
#   101,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-10-26',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '58',
#   '92',
#   '---',
#   '16',
#   '29',
#   '24',
#   92,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-27',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '53',
#   '76',
#   '---',
#   '11',
#   '32',
#   '17',
#   76,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-28',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '51',
#   '77',
#   '---',
#   '16',
#   '29',
#   '27',
#   77,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-29',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '50',
#   '70',
#   '---',
#   '18',
#   '23',
#   '33',
#   70,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-30',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '50',
#   '74',
#   '---',
#   '12',
#   '30',
#   '24',
#   74,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-10-31',
#   'DKI5 (Kebon Jeruk) Jakarta Barat',
#   '49',
#   '74',
#   '---',
#   '10',
#   '31',
#   '13',
#   74,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-01',
#   'DKI1 (Bunderan HI)',
#   '63',
#   '88',
#   '29',
#   '15',
#   '24',
#   '38',
#   88,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-02',
#   'DKI1 (Bunderan HI)',
#   '60',
#   '83',
#   '29',
#   '11',
#   '30',
#   '28',
#   83,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-03',
#   'DKI1 (Bunderan HI)',
#   '60',
#   '82',
#   '27',
#   '11',
#   '37',
#   '30',
#   82,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-04',
#   'DKI1 (Bunderan HI)',
#   '58',
#   '77',
#   '26',
#   '10',
#   '31',
#   '28',
#   77,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-05',
#   'DKI1 (Bunderan HI)',
#   '63',
#   '85',
#   '27',
#   '11',
#   '28',
#   '28',
#   85,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-06',
#   'DKI1 (Bunderan HI)',
#   '68',
#   '92',
#   '31',
#   '11',
#   '26',
#   '24',
#   92,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-07',
#   'DKI1 (Bunderan HI)',
#   '52',
#   '65',
#   '28',
#   '9',
#   '19',
#   '24',
#   65,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-08',
#   'DKI1 (Bunderan HI)',
#   '53',
#   '76',
#   '25',
#   '16',
#   '23',
#   '34',
#   76,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-09',
#   'DKI1 (Bunderan HI)',
#   '45',
#   '62',
#   '25',
#   '12',
#   '27',
#   '31',
#   62,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-10',
#   'DKI1 (Bunderan HI)',
#   '51',
#   '66',
#   '27',
#   '10',
#   '25',
#   '32',
#   66,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-11',
#   'DKI1 (Bunderan HI)',
#   '66',
#   '93',
#   '32',
#   '12',
#   '34',
#   '41',
#   93,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-12',
#   'DKI1 (Bunderan HI)',
#   '61',
#   '80',
#   '26',
#   '10',
#   '28',
#   '27',
#   80,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-13',
#   'DKI1 (Bunderan HI)',
#   '51',
#   '64',
#   '29',
#   '8',
#   '23',
#   '21',
#   64,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-14',
#   'DKI1 (Bunderan HI)',
#   '31',
#   '42',
#   '24',
#   '8',
#   '20',
#   '19',
#   42,
#   'PM25',
#   'BAIK',
#   None),
#  ('2021-09-15',
#   'DKI1 (Bunderan HI)',
#   '54',
#   '81',
#   '29',
#   '20',
#   '20',
#   '45',
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-16',
#   'DKI1 (Bunderan HI)',
#   '48',
#   '65',
#   '29',
#   '9',
#   '23',
#   '24',
#   65,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-17',
#   'DKI1 (Bunderan HI)',
#   '42',
#   '66',
#   '29',
#   '7',
#   '26',
#   '20',
#   66,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-18',
#   'DKI1 (Bunderan HI)',
#   '50',
#   '73',
#   '29',
#   '8',
#   '23',
#   '22',
#   73,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-19',
#   'DKI1 (Bunderan HI)',
#   '53',
#   '78',
#   '26',
#   '8',
#   '33',
#   '19',
#   78,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-20',
#   'DKI1 (Bunderan HI)',
#   '51',
#   '69',
#   '27',
#   '10',
#   '25',
#   '34',
#   69,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-21',
#   'DKI1 (Bunderan HI)',
#   '55',
#   '81',
#   '28',
#   '11',
#   '29',
#   '36',
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-22',
#   'DKI1 (Bunderan HI)',
#   '57',
#   '80',
#   '29',
#   '11',
#   '24',
#   '32',
#   80,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-23',
#   'DKI1 (Bunderan HI)',
#   '54',
#   '80',
#   '29',
#   '8',
#   '27',
#   '22',
#   80,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-24',
#   'DKI1 (Bunderan HI)',
#   '57',
#   '74',
#   '34',
#   '8',
#   '20',
#   '26',
#   74,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-25',
#   'DKI1 (Bunderan HI)',
#   '49',
#   '67',
#   '31',
#   '7',
#   '24',
#   '20',
#   67,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-26',
#   'DKI1 (Bunderan HI)',
#   '52',
#   '72',
#   '28',
#   '6',
#   '28',
#   '19',
#   72,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-27',
#   'DKI1 (Bunderan HI)',
#   '51',
#   '72',
#   '27',
#   '12',
#   '22',
#   '33',
#   72,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-28',
#   'DKI1 (Bunderan HI)',
#   '45',
#   '63',
#   '25',
#   '9',
#   '24',
#   '28',
#   63,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-29',
#   'DKI1 (Bunderan HI)',
#   '54',
#   '76',
#   '26',
#   '12',
#   '29',
#   '38',
#   76,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-30',
#   'DKI1 (Bunderan HI)',
#   '63',
#   '94',
#   '27',
#   '13',
#   '38',
#   '37',
#   94,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-01',
#   'DKI2 (Kelapa Gading)',
#   '79',
#   '102',
#   '55',
#   '14',
#   '30',
#   '29',
#   102,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-09-02',
#   'DKI2 (Kelapa Gading)',
#   '66',
#   '89',
#   '52',
#   '10',
#   '39',
#   '19',
#   89,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-03',
#   'DKI2 (Kelapa Gading)',
#   '66',
#   '87',
#   '51',
#   '9',
#   '39',
#   '18',
#   87,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-04',
#   'DKI2 (Kelapa Gading)',
#   '62',
#   '79',
#   '50',
#   '9',
#   '37',
#   '18',
#   79,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-05',
#   'DKI2 (Kelapa Gading)',
#   '74',
#   '100',
#   '52',
#   '12',
#   '35',
#   '22',
#   100,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-06',
#   'DKI2 (Kelapa Gading)',
#   '66',
#   '87',
#   '51',
#   '10',
#   '34',
#   '13',
#   87,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-07',
#   'DKI2 (Kelapa Gading)',
#   '58',
#   '72',
#   '51',
#   '9',
#   '27',
#   '16',
#   72,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-08',
#   'DKI2 (Kelapa Gading)',
#   '64',
#   '87',
#   '52',
#   '13',
#   '27',
#   '31',
#   87,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-09',
#   'DKI2 (Kelapa Gading)',
#   '68',
#   '88',
#   '54',
#   '12',
#   '35',
#   '29',
#   88,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-10',
#   'DKI2 (Kelapa Gading)',
#   '58',
#   '77',
#   '53',
#   '9',
#   '32',
#   '20',
#   77,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-11',
#   'DKI2 (Kelapa Gading)',
#   '70',
#   '99',
#   '53',
#   '11',
#   '46',
#   '22',
#   99,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-12',
#   'DKI2 (Kelapa Gading)',
#   '66',
#   '82',
#   '51',
#   '9',
#   '36',
#   '12',
#   82,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-13',
#   'DKI2 (Kelapa Gading)',
#   '56',
#   '71',
#   '52',
#   '9',
#   '27',
#   '14',
#   71,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-14',
#   'DKI2 (Kelapa Gading)',
#   '36',
#   '47',
#   '50',
#   '8',
#   '47',
#   '15',
#   50,
#   'SO2',
#   'BAIK',
#   None),
#  ('2021-09-15',
#   'DKI2 (Kelapa Gading)',
#   '69',
#   '95',
#   '54',
#   '17',
#   '45',
#   '35',
#   95,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-16',
#   'DKI2 (Kelapa Gading)',
#   '52',
#   '66',
#   '52',
#   '8',
#   '52',
#   '15',
#   66,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-17',
#   'DKI2 (Kelapa Gading)',
#   '46',
#   '66',
#   '51',
#   '7',
#   '53',
#   '9',
#   66,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-18',
#   'DKI2 (Kelapa Gading)',
#   '56',
#   '79',
#   '53',
#   '8',
#   '51',
#   '15',
#   79,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-19',
#   'DKI2 (Kelapa Gading)',
#   '52',
#   '73',
#   '50',
#   '8',
#   '68',
#   '10',
#   73,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-20',
#   'DKI2 (Kelapa Gading)',
#   '58',
#   '81',
#   '52',
#   '11',
#   '54',
#   '25',
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-21',
#   'DKI2 (Kelapa Gading)',
#   '61',
#   '85',
#   '52',
#   '10',
#   '58',
#   '19',
#   85,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-22',
#   'DKI2 (Kelapa Gading)',
#   '64',
#   '82',
#   '54',
#   '10',
#   '48',
#   '22',
#   82,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-23',
#   'DKI2 (Kelapa Gading)',
#   '61',
#   '85',
#   '53',
#   '8',
#   '53',
#   '13',
#   85,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-24',
#   'DKI2 (Kelapa Gading)',
#   '57',
#   '76',
#   '53',
#   '8',
#   '47',
#   '13',
#   76,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-25',
#   'DKI2 (Kelapa Gading)',
#   '55',
#   '81',
#   '52',
#   '8',
#   '50',
#   '13',
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-26',
#   'DKI2 (Kelapa Gading)',
#   '56',
#   '74',
#   '---',
#   '7',
#   '54',
#   '6',
#   74,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-27',
#   'DKI2 (Kelapa Gading)',
#   '53',
#   '77',
#   '---',
#   '11',
#   '47',
#   '17',
#   77,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-28',
#   'DKI2 (Kelapa Gading)',
#   '49',
#   '71',
#   '---',
#   '8',
#   '49',
#   '13',
#   71,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-29',
#   'DKI2 (Kelapa Gading)',
#   '54',
#   '81',
#   '57',
#   '10',
#   '63',
#   '16',
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-30',
#   'DKI2 (Kelapa Gading)',
#   '71',
#   '105',
#   '63',
#   '12',
#   '63',
#   '24',
#   105,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-09-01',
#   'DKI3 (Jagakarsa)',
#   '57',
#   '83',
#   '46',
#   '13',
#   '32',
#   '14',
#   83,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-02',
#   'DKI3 (Jagakarsa)',
#   '65',
#   '99',
#   '46',
#   '15',
#   '29',
#   '16',
#   99,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-03',
#   'DKI3 (Jagakarsa)',
#   '56',
#   '86',
#   '45',
#   '9',
#   '39',
#   '13',
#   86,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-04',
#   'DKI3 (Jagakarsa)',
#   '53',
#   '77',
#   '45',
#   '9',
#   '30',
#   '13',
#   77,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-05',
#   'DKI3 (Jagakarsa)',
#   '61',
#   '93',
#   '46',
#   '11',
#   '36',
#   '14',
#   93,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-06',
#   'DKI3 (Jagakarsa)',
#   '73',
#   '108',
#   '48',
#   '13',
#   '29',
#   '15',
#   108,
#   'PM25',
#   'TIDAK SEHAT',
#   None),
#  ('2021-09-07',
#   'DKI3 (Jagakarsa)',
#   '60',
#   '84',
#   '48',
#   '11',
#   '26',
#   '15',
#   84,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-08',
#   'DKI3 (Jagakarsa)',
#   '60',
#   '82',
#   '48',
#   '12',
#   '29',
#   '15',
#   82,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-09',
#   'DKI3 (Jagakarsa)',
#   '48',
#   '61',
#   '46',
#   '9',
#   '31',
#   '12',
#   61,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-10',
#   'DKI3 (Jagakarsa)',
#   '49',
#   '71',
#   '49',
#   '9',
#   '36',
#   '15',
#   71,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-11',
#   'DKI3 (Jagakarsa)',
#   '61',
#   '89',
#   '50',
#   '10',
#   '43',
#   '16',
#   89,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-12',
#   'DKI3 (Jagakarsa)',
#   '55',
#   '78',
#   '47',
#   '9',
#   '30',
#   '13',
#   78,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-13',
#   'DKI3 (Jagakarsa)',
#   '51',
#   '65',
#   '47',
#   '8',
#   '26',
#   '11',
#   65,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-14',
#   'DKI3 (Jagakarsa)',
#   '32',
#   '51',
#   '46',
#   '7',
#   '21',
#   '11',
#   51,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-15',
#   'DKI3 (Jagakarsa)',
#   '53',
#   '81',
#   '50',
#   '17',
#   '24',
#   '22',
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-16',
#   'DKI3 (Jagakarsa)',
#   '51',
#   '72',
#   '50',
#   '10',
#   '27',
#   '15',
#   72,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-17',
#   'DKI3 (Jagakarsa)',
#   '47',
#   '72',
#   '49',
#   '7',
#   '29',
#   '13',
#   72,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-18',
#   'DKI3 (Jagakarsa)',
#   '55',
#   '80',
#   '50',
#   '9',
#   '27',
#   '15',
#   80,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-19',
#   'DKI3 (Jagakarsa)',
#   '56',
#   '81',
#   '48',
#   '10',
#   '31',
#   '12',
#   81,
#   'PM25',
#   'SEDANG',
#   None),
#  ('2021-09-20',
#   'DKI3 (Jagakarsa)',
#   '45',
#   '59',
#   '49',
#   '7',
#   '33',
#   '10',
#   59,
#   'PM25',
#   'SEDANG',
#   None),
#  ...]

# %%
def create_dataframe_from_query_result(data: list) -> pd.DataFrame:
    '''
    Brief:
    This function intended to convert query result to Pandas DataFrame.

    Params:
    1.  data
        List, object that has one or more elements as result from query.
    
    Return:
    1.  data
        Pandas DataFrame, DataFrame version of data.
    '''
    data = pd.DataFrame(data)
    
    return data

# %%
dataset = create_dataframe_from_query_result(result)

# %%
dataset
# Out:
#               0                                 1   2    3    4   5   6   7   \
# 0     2021-08-01                DKI1 (Bunderan HI)  51   68   25   8  29  22
# 1     2021-08-02                DKI1 (Bunderan HI)  47   63   24  10  25  28
# 2     2021-08-03                DKI1 (Bunderan HI)  50   68   26  11  19  35
# 3     2021-08-04                DKI1 (Bunderan HI)  52   70   29   8  24  26
# 4     2021-08-05                DKI1 (Bunderan HI)  52   66   29   9  21  27
# ...          ...                               ...  ..  ...  ...  ..  ..  ..
# 1065  2021-09-26  DKI5 (Kebon Jeruk) Jakarta Barat  48   67  ---   4  30   9
# 1066  2021-09-27  DKI5 (Kebon Jeruk) Jakarta Barat  51   78  ---   9  22  18
# 1067  2021-09-28  DKI5 (Kebon Jeruk) Jakarta Barat  42   64  ---   5  26  14
# 1068  2021-09-29  DKI5 (Kebon Jeruk) Jakarta Barat  56   87  ---  11  34  19
# 1069  2021-09-30  DKI5 (Kebon Jeruk) Jakarta Barat  68  108  ---  10  46  13
#
#        8     9            10    11
# 0      68  PM25       SEDANG  None
# 1      63  PM25       SEDANG  None
# 2      68  PM25       SEDANG  None
# 3      70  PM25       SEDANG  None
# 4      66  PM25       SEDANG  None
# ...   ...   ...          ...   ...
# 1065   67  PM25       SEDANG  None
# 1066   78  PM25       SEDANG  None
# 1067   64  PM25       SEDANG  None
# 1068   87  PM25       SEDANG  None
# 1069  108  PM25  TIDAK SEHAT  None
#
# [1070 rows x 12 columns]

# %%
def get_columns_name_from_query(cursor: sqlite3.Cursor, table_name: str) -> list:
    '''
    Brief:
    This function intended to get columns name of particular table in database.

    Params:
    1.  cursor
        Sqlite3 cursor object, object that has capability to access and do traversal in target database.
        
    2.  table_name
        String, name of target table.
    
    Return:
    1.  columns_name
        List, list of columns name in target table.
    '''
    result = execute_query(cursor, "PRAGMA table_info({})".format(table_name))
    columns_name = [item[1] for item in result]

    return columns_name

# %%
columns_name = get_columns_name_from_query(cursor, "ispu")

# %%
columns_name
# Out:
# ['tanggal',
#  'stasiun',
#  'pm10',
#  'pm25',
#  'so2',
#  'co',
#  'o3',
#  'no2',
#  'max',
#  'critical',
#  'categori',
#  'location']

# %%
def assign_column_name_to_dataframe(target_dataframe: pd.DataFrame, columns_name: list) -> pd.DataFrame:
    '''
    Brief:
    This function intended to assign new columns name to a dataframe object, make sure that the order and lenght is correct.

    Params:
    1.  target_dataframe
        Pandas DataFrame, object that user wanted to change the columns name.
    
    2.  columns_name
        List, object that contains new columns name.
    
    Return:
    1.  target_dataframe
        Pandas DataFrame, target_dataframe but with new columns name.
    '''
    target_dataframe = target_dataframe.copy(deep=True)
    target_dataframe.columns = columns_name

    return target_dataframe

# %%
dataset = assign_column_name_to_dataframe(dataset, columns_name)

# %%
dataset
# Out:
#          tanggal                           stasiun pm10 pm25  so2  co  o3 no2  \
# 0     2021-08-01                DKI1 (Bunderan HI)   51   68   25   8  29  22
# 1     2021-08-02                DKI1 (Bunderan HI)   47   63   24  10  25  28
# 2     2021-08-03                DKI1 (Bunderan HI)   50   68   26  11  19  35
# 3     2021-08-04                DKI1 (Bunderan HI)   52   70   29   8  24  26
# 4     2021-08-05                DKI1 (Bunderan HI)   52   66   29   9  21  27
# ...          ...                               ...  ...  ...  ...  ..  ..  ..
# 1065  2021-09-26  DKI5 (Kebon Jeruk) Jakarta Barat   48   67  ---   4  30   9
# 1066  2021-09-27  DKI5 (Kebon Jeruk) Jakarta Barat   51   78  ---   9  22  18
# 1067  2021-09-28  DKI5 (Kebon Jeruk) Jakarta Barat   42   64  ---   5  26  14
# 1068  2021-09-29  DKI5 (Kebon Jeruk) Jakarta Barat   56   87  ---  11  34  19
# 1069  2021-09-30  DKI5 (Kebon Jeruk) Jakarta Barat   68  108  ---  10  46  13
#
#       max critical     categori location
# 0      68     PM25       SEDANG     None
# 1      63     PM25       SEDANG     None
# 2      68     PM25       SEDANG     None
# 3      70     PM25       SEDANG     None
# 4      66     PM25       SEDANG     None
# ...   ...      ...          ...      ...
# 1065   67     PM25       SEDANG     None
# 1066   78     PM25       SEDANG     None
# 1067   64     PM25       SEDANG     None
# 1068   87     PM25       SEDANG     None
# 1069  108     PM25  TIDAK SEHAT     None
#
# [1070 rows x 12 columns]

# %% [markdown]
# ## 4.4. Drop Duplicate

# %% [markdown]
# #### 4.4.1. Check for duplipcate

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### 4.4.2. Adding some same data to demonstrate dropping duplicate

# %%
new_same_data = dataset[dataset["tanggal"] == "2021-08-01"].reset_index(drop=True)

# %%
new_same_data
# Out:
#       tanggal                           stasiun pm10 pm25 so2 co  o3 no2 max  \
# 0  2021-08-01                DKI1 (Bunderan HI)   51   68  25  8  29  22  68
# 1  2021-08-01              DKI2 (Kelapa Gading)   55   75  50  9  67  13  75
# 2  2021-08-01                  DKI3 (Jagakarsa)   51   66  44  9  31  11  66
# 3  2021-08-01               DKI4 (Lubang Buaya)   51   86  39  8  30  22  86
# 4  2021-08-01  DKI5 (Kebon Jeruk) Jakarta Barat   44   70  30  8  29  11  70
#
#   critical categori location
# 0     PM25   SEDANG     None
# 1     PM25   SEDANG     None
# 2     PM25   SEDANG     None
# 3     PM25   SEDANG     None
# 4     PM25   SEDANG     None

# %%
dataset = pd.concat([dataset, new_same_data])

# %%
dataset.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### 4.4.3. Rechecking duplicate data

# %%
duplicate_data = dataset.duplicated(keep=False)

# %%
duplicate_data
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1070     True
# 1071     True
# 1072     True
# 1073     True
# 1074     True
# Length: 1075, dtype: bool

# %%
duplicate_data_index = duplicate_data[duplicate_data == True].index

# %%
duplicate_data_index
# Out:
# Index([0, 31, 62, 93, 124, 1070, 1071, 1072, 1073, 1074], dtype='int64')

# %%
dataset.loc[duplicate_data_index].sort_values(by="stasiun")
# Out:
#          tanggal                           stasiun pm10 pm25 so2 co  o3 no2  \
# 0     2021-08-01                DKI1 (Bunderan HI)   51   68  25  8  29  22
# 1070  2021-08-01                DKI1 (Bunderan HI)   51   68  25  8  29  22
# 31    2021-08-01              DKI2 (Kelapa Gading)   55   75  50  9  67  13
# 1071  2021-08-01              DKI2 (Kelapa Gading)   55   75  50  9  67  13
# 62    2021-08-01                  DKI3 (Jagakarsa)   51   66  44  9  31  11
# 1072  2021-08-01                  DKI3 (Jagakarsa)   51   66  44  9  31  11
# 93    2021-08-01               DKI4 (Lubang Buaya)   51   86  39  8  30  22
# 1073  2021-08-01               DKI4 (Lubang Buaya)   51   86  39  8  30  22
# 124   2021-08-01  DKI5 (Kebon Jeruk) Jakarta Barat   44   70  30  8  29  11
# 1074  2021-08-01  DKI5 (Kebon Jeruk) Jakarta Barat   44   70  30  8  29  11
#
#      max critical categori location
# 0     68     PM25   SEDANG     None
# 1070  68     PM25   SEDANG     None
# 31    75     PM25   SEDANG     None
# 1071  75     PM25   SEDANG     None
# 62    66     PM25   SEDANG     None
# 1072  66     PM25   SEDANG     None
# 93    86     PM25   SEDANG     None
# 1073  86     PM25   SEDANG     None
# 124   70     PM25   SEDANG     None
# 1074  70     PM25   SEDANG     None

# %%
dataset.duplicated().sum()
# Out:
# 5

# %% [markdown]
# #### 4.4.4. Dropping duplicate

# %%
def dropping_duplicate(target_dataframe: pd.DataFrame, subset: list=[]) -> pd.DataFrame:
    '''
    Brief:
    This function intended to drop duplicate on all or only particular column in a dataframe.

    Params:
    1.  target_dataframe
        Pandas DataFrame, object that user wanted to drop the duplicate data.
    
    2.  subset
        List, object that contains name of column user wanted to drop duplicate.
    
    Return:
    1.  target_dataframe
        Pandas DataFrame, target_dataframe but with dropped duplicate.
    '''
    target_dataframe = target_dataframe.copy(deep=True)
    if(subset == []):
        target_dataframe.drop_duplicates(inplace=True)
    else:
        target_dataframe.drop_duplicates(inplace=True, subset=subset)
    
    return target_dataframe

# %%
dataset = dropping_duplicate(dataset)

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 4.5. Serialization

# %%
def save_data(data: any, save_path: str) -> None:
    '''
    Brief:
    This function intended to serialize data in RAM to file in disk.

    Params:
    1.  data
        Any, object that user wanted to save.
    
    2.  save_path
        str, location of saved data.
    
    Return:
    None.
    '''
    joblib.dump(data, save_path)

# %%
save_data(dataset, "../data/processed/dataset.pkl")
